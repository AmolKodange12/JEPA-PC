# %% [markdown]
# # Stage 3 — PC on Patch Tokens (Partial Composite)

# %% [markdown]
# ## Setup

# %%
# imports and config

# %% [markdown]
# ## Load Frozen JEPA Tokenizer

# %% [markdown]
# ## PC Hierarchy on Token Space

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Verification
#
# - [ ] PC inference converges in fewer iterations than pixel-space PC
# - [ ] Linear probe accuracy increases with PC level
# - [ ] Prediction errors are high on occluded/ambiguous patches
