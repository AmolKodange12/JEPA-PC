# %% [markdown]
# # Stage 4 — Full Composite + Evaluation

# %% [markdown]
# ## Setup

# %%
# imports and config

# %% [markdown]
# ## Evaluation 1: Inference-Time Adaptation
#
# Does iterative PC inference improve representations over a single forward pass?

# %% [markdown]
# ## Evaluation 2: Continual Learning
#
# Do local PC weight updates reduce catastrophic forgetting vs. backprop-trained JEPA?

# %% [markdown]
# ## Evaluation 3: Uncertainty via Precision-Weighting
#
# Do PC precision estimates highlight informative/uncertain image regions?
