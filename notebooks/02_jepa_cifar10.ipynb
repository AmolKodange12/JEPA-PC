# %% [markdown]
# # Stage 2 — JEPA Tokenizer on CIFAR-10

# %% [markdown]
# ## Setup

# %%
# imports and config

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ## Model Definition

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Verification
#
# - [ ] Representation variance does not collapse to zero
# - [ ] Linear probe accuracy ≥ 60% on CIFAR-10
# - [ ] Nearest-neighbor visualization in embedding space
# - [ ] EMA target encoder weights diverge from online encoder
